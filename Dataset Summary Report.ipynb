# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c141548c-d6ff-4ac7-b9de-9eb4dca52c39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c141548c-d6ff-4ac7-b9de-9eb4dca52c39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Day7_Student_Dataset.csv")
print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#    Student_ID          Name  Age            Course  Marks  \
# 0        1001  Aarav Sharma   19      Data Science   87.0
# 1        1002     Zoya Khan   20                AI   92.0
# 2        1003   Rohan Mehta   18  Computer Science   76.0
# 3        1004  Ananya Singh   21      Data Science   81.0
# 4        1005     Kabir Ali   19                AI   69.0
#
#    Attendance_Percentage      City
# 0                   91.0  Srinagar
# 1                   95.0     Delhi
# 2                   82.0    Mumbai
# 3                   88.0  Srinagar
# 4                   76.0   Lucknow

# %%
df.tail()
# Out:
#     Student_ID          Name  Age            Course  Marks  \
# 20        1021    Aman Kumar   18  Computer Science   74.0
# 21        1022    Alina Shah   19      Data Science   96.0
# 22        1023   Nikhil Sood   22                AI   78.0
# 23        1024   Maryam Khan   20  Computer Science   85.0
# 24        1025  Reyansh Jain   21      Data Science   80.0
#
#     Attendance_Percentage       City
# 20                   78.0      Delhi
# 21                   98.0   Srinagar
# 22                   83.0       Pune
# 23                   88.0  Hyderabad
# 24                   84.0    Kolkata

# %%
df.sample(5)
# Out:
#     Student_ID          Name  Age            Course  Marks  \
# 14        1015   Karan Joshi   20  Computer Science   77.0
# 23        1024   Maryam Khan   20  Computer Science   85.0
# 6         1007  Aditya Verma   22      Data Science   95.0
# 16        1017     Dev Patel   19                AI   86.0
# 22        1023   Nikhil Sood   22                AI   78.0
#
#     Attendance_Percentage        City
# 14                   85.0  Chandigarh
# 23                   88.0   Hyderabad
# 6                    97.0        Pune
# 16                   89.0   Ahmedabad
# 22                   83.0        Pune

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print("Shape of dataset:", df.shape)
# Out:
# Number of rows: 25
# Number of columns: 7
# Shape of dataset: (25, 7)

# %%
print("Column names:")
print(df.columns)
# Out:
# Column names:
# Index(['Student_ID', 'Name', 'Age', 'Course', 'Marks', 'Attendance_Percentage',
#        'City'],
#       dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
print(df.dtypes)
# Out:
# Student_ID                 int64
# Name                      object
# Age                        int64
# Course                    object
# Marks                    float64
# Attendance_Percentage    float64
# City                      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             25 non-null     int64
#  1   Name                   25 non-null     object
#  2   Age                    25 non-null     int64
#  3   Course                 25 non-null     object
#  4   Marks                  24 non-null     float64
#  5   Attendance_Percentage  24 non-null     float64
#  6   City                   24 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#         Student_ID        Age      Marks  Attendance_Percentage
# count    25.000000  25.000000  24.000000              24.000000
# mean   1013.000000  20.000000  82.250000              87.083333
# std       7.359801   1.414214   8.689074               7.252686
# min    1001.000000  18.000000  68.000000              72.000000
# 25%    1007.000000  19.000000  75.500000              82.750000
# 50%    1013.000000  20.000000  82.500000              88.000000
# 75%    1019.000000  21.000000  89.250000              92.250000
# max    1025.000000  23.000000  96.000000              98.000000

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Student_ID               0
# Name                     0
# Age                      0
# Course                   0
# Marks                    1
# Attendance_Percentage    1
# City                     1
# dtype: int64

# %%
total_missing = df.isnull().sum().sum()
print("Total missing values:", total_missing)
# Out:
# Total missing values: 3

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
print("DATASET SUMMARY")
print("----------------")
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print("\nFeatures:")
for column in df.columns:
    print("-", column)
print("\nData Types:")
print(df.dtypes)
print("\nMissing Values:")
print(df.isnull().sum())
print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# DATASET SUMMARY
# ----------------
# Number of rows: 25
# Number of columns: 7
#
# Features:
# - Student_ID
# - Name
# - Age
# - Course
# - Marks
# - Attendance_Percentage
# - City
#
# Data Types:
# Student_ID                 int64
# Name                      object
# Age                        int64
# Course                    object
# Marks                    float64
# Attendance_Percentage    float64
# City                      object
# dtype: object
#
# Missing Values:
# Student_ID               0
# Name                     0
# Age                      0
# Course                   0
# Marks                    1
# Attendance_Percentage    1
# City                     1
# dtype: int64
#
# Duplicate Rows:
# 0

# %%
##Basic Observations
# The dataset contains 25 student records.
# The dataset contains 7 columns/features.
# The available features are Student_ID, Name, Age, Course, Marks, Attendance_Percentage, and City.
# The dataset contains both numerical and categorical data.
# Marks and Attendance_Percentage are numerical features.
# Name, Course, and City are categorical/text features.
# Missing values are present in Attendance_Percentage and City.
# Duplicate records can be checked using the `duplicated()` function.
# The `describe()` function provides useful statistics for numerical columns.
